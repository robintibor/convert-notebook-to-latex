# %%
from matplotlib import pyplot
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
matplotlib.rcParams['figure.figsize'] = (8.0, 2.0)

# %% [markdown]
# ## example
# Hi this is an example

# %%
pyplot.plot([0,1])

# %% [markdown]
# $1 = 2 \ inlinelatex$
#
# $$ equation = equation $$

# %% [markdown]
# |id|files|sel_feat|for|back|stop_improve|sel_filt|time|std|test|std|train|std|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |0|18|10|1|0|False|None|0:01:26|0:00:06|86.16%|9.60%|99.54%|0.59%|
# |1|18|10|2|1|False|None|0:02:52|0:00:10|85.84%|9.59%|99.60%|0.53%|
# |2|18|10|4|2|False|None|0:03:39|0:00:14|86.28%|9.39%|99.71%|0.40%|
# |3|18|10|1|0|False|10|0:00:33|0:00:03|85.77%|10.68%|99.51%|0.63%|
# |4|18|10|2|1|False|10|0:01:00|0:00:05|85.74%|10.35%|99.58%|0.54%|
# |5|18|10|4|2|False|10|0:01:15|0:00:07|86.41%|10.02%|99.74%|0.37%|
# |6|18|10|1|0|False|20|0:00:54|0:00:04|86.94%|9.69%|99.58%|0.56%|
# |7|18|10|2|1|False|20|0:01:44|0:00:07|86.74%|9.88%|99.63%|0.50%|
# |8|18|10|4|2|False|20|0:02:11|0:00:09|87.70%|9.04%|99.76%|0.36%|
# |9|18|10|1|0|True|None|0:01:08|0:00:13|86.32%|9.62%|99.43%|0.59%|
# |10|18|10|2|1|True|None|0:02:12|0:00:26|86.22%|9.66%|99.49%|0.55%|

# %% [markdown]
# <span class="todecide">blabla</span>

# %% [markdown]
# ```python
# def hi(bla):
#     print("wow code")
# ```
#
# ```
# Input: bla
# WOW PSEUDOCODE
# ```

# %% [markdown]
# <div class="summary">
# <ul>
# <li>yap</li>
# <li>yup</li>
# </ul>
# </div>

# %% [markdown]
# blublub
# <img src="https://dl.dropboxusercontent.com/u/34637013/work/machine-learning-for-motor-imagery/ipython-notebooks/svgs/architectures/raw_square_explanation.svg?cache=no10"></img>
# blabla
# <img src="https://dl.dropboxusercontent.com/u/34637013/work/machine-learning-for-motor-imagery/ipython-notebooks/svgs/architectures/csp_as_a_net_explanation.svg?cache=no10"></img>
# lababa

# %% [markdown]
# <img src="http://ieeexplore.ieee.org/ielx5/79/4404853/4408441/html/img/4408441-fig-3-small.gif"></img>

# %%
# %%javascript
# var a=1

# %%
# %%html
# <style>
# </style
# Out:
# <style>
# </style

# %%
# test for no output cell hehe
1
None

# %% [markdown]
# [A github link](https://github.com/robintibor)

# %% [markdown]
# Hm da kommt das local bild
# ![Some image file](./example-image-head.jpg)
#
#
# blabla

# %% [markdown]
# ![](./example-image-head.jpg)

# %% [markdown]
# Weird image in parnt folder
# ![](../example-image-head.jpg "title")

# %% [markdown]
# Funny image in sub folder
# ![](image-subfolder/example-image-head.jpg)

# %% [markdown]
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
#
#
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
#
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
#
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
# A longer text which is longer and has paragraphs.
